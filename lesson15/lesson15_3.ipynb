# %%
import numpy as np 
scores = np.random.randint(50,101,size=(50,5))
scores
# Out:
# array([[ 80,  64,  62, 100,  53],
#        [ 53,  53,  87,  82,  76],
#        [ 52,  78,  84,  71,  81],
#        [ 56,  55,  60,  83,  71],
#        [ 82,  54,  72,  67,  90],
#        [ 70,  84,  90,  78,  73],
#        [ 97,  96,  95,  60,  54],
#        [ 59,  58,  99,  88,  83],
#        [100,  80,  86,  58,  66],
#        [ 74,  51,  53,  77,  69],
#        [ 88,  66,  67,  62,  89],
#        [ 67,  85,  89,  50,  85],
#        [ 92,  78,  72,  53,  57],
#        [ 67,  83,  73,  81,  69],
#        [ 99,  56,  62,  67,  54],
#        [ 99,  51,  92,  87,  68],
#        [ 60,  53,  75,  63,  73],
#        [ 64,  93,  99,  92,  94],
#        [ 65,  61,  76,  96,  95],
#        [ 97,  69, 100,  66,  52],
#        [ 85,  94,  96,  67,  96],
#        [ 69,  52,  59,  89,  56],
#        [ 93,  93,  91,  62,  67],
#        [ 81,  52,  87,  94,  50],
#        [ 58, 100,  73,  99,  60],
#        [ 70,  95,  57,  51,  55],
#        [ 52,  63,  98,  94,  59],
# ...

# %%
import pandas as pd

df = pd.DataFrame(scores,
             index= [f"學生{i}"for i in range(50)],
             columns = ["國文","英文","數學","地理","歷史"]   
)
df
# Out:
#        國文   英文   數學   地理   歷史
# 學生0    80   64   62  100   53
# 學生1    53   53   87   82   76
# 學生2    52   78   84   71   81
# 學生3    56   55   60   83   71
# 學生4    82   54   72   67   90
# 學生5    70   84   90   78   73
# 學生6    97   96   95   60   54
# 學生7    59   58   99   88   83
# 學生8   100   80   86   58   66
# 學生9    74   51   53   77   69
# 學生10   88   66   67   62   89
# 學生11   67   85   89   50   85
# 學生12   92   78   72   53   57
# 學生13   67   83   73   81   69
# 學生14   99   56   62   67   54
# 學生15   99   51   92   87   68
# 學生16   60   53   75   63   73
# 學生17   64   93   99   92   94
# 學生18   65   61   76   96   95
# 學生19   97   69  100   66   52
# 學生20   85   94   96   67   96
# 學生21   69   52   59   89   56
# 學生22   93   93   91   62   67
# 學生23   81   52   87   94   50
# 學生24   58  100   73   99   60
# 學生25   70   95   57   51   55
# 學生26   52   63   98   94   59
# 學生27   84   73   66   97   98
# 學生28   88   85   85   57   65
# 學生29   69   88   96   73   70
# ...

# %%
df [-1:]
# Out:
#       國文   英文  數學  地理  歷史
# 學生43  50  100  82  87  96
# 學生44  63   61  83  95  85
# 學生45  87   56  74  71  52
# 學生46  55   92  75  56  78
# 學生47  69   78  85  82  89
# 學生48  68   76  63  97  80
# 學生49  62   57  59  75  83
